# %%
import pandas as pd 
import matplotlib as plt 
import numpy as np 
import os

# %%
df = pd.read_csv("lifestyle_dataset.csv")
df.head()
# Out:
#    Age Gender  Occupation  Height_cm  Weight_kg    Country          Archetype  \
# 0   56      M     Manager      180.4       96.0         UK  Health Enthusiast
# 1   46      M     Student      180.7       78.7     France            Student
# 2   32      F  Unemployed      169.9       55.8      India            Student
# 3   60      F     Teacher      172.1       64.6     Canada         Workaholic
# 4   25      F     Student      156.5       53.5  Australia          Sedentary
#
#    DailyCalorieIntake  SleepHours  PhysicalActivity_min  ...  ScreenTime_hrs  \
# 0                2602         8.2                    64  ...             4.1
# 1                2226         6.9                    52  ...             5.3
# 2                1943         5.0                    18  ...             6.4
# 3                1933         5.7                    30  ...            10.9
# 4                1876         6.3                     2  ...             3.0
#
# ...

# %%
len(df)
# Out:
# 10000
