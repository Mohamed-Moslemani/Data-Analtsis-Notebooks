# %% [markdown]
# # **Crops Comodoties Analysis**

# %% [markdown]
# ### Necessary imports

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import plotly
import seaborn as sns
import numpy 
import os 
import sys
from termcolor import colored
from datetime import datetime
import mplfinance as mpf

# %% [markdown]
# #### directory management and path setting

# %%
DATA_DIR_PATH =  "src"

all_grains_df = pd.read_csv(os.path.join(DATA_DIR_PATH,"all_grains_data.csv"))
corn_df = pd.read_csv(os.path.join(DATA_DIR_PATH,"Corn_data.csv"))
wheat_df = pd.read_csv(os.path.join(DATA_DIR_PATH,"KC_HRW_Wheat_data.csv"))
oat_df = pd.read_csv(os.path.join(DATA_DIR_PATH,'Oat_data.csv'))
rice_df = pd.read_csv(os.path.join(DATA_DIR_PATH,'Rough_Rice_data.csv'))
soybean_df = pd.read_csv(os.path.join(DATA_DIR_PATH,'Soybean_data.csv'))
soybean_oil_df = pd.read_csv(os.path.join(DATA_DIR_PATH,'Soybean_Oil_data.csv'))

dfs_arr = [all_grains_df,corn_df,wheat_df,oat_df,rice_df,soybean_df,soybean_oil_df]
dfs_names_arr = ["all grains","corn",'wheat','oat','rice','soybean','soybean oil']

# %% [markdown]
# #### initial inspection

# %%
for df in dfs_arr:
    print(df.head(5))
    print("------------------------------------------------------------------------------")
# Out:
#   ticker commodity        date    open    high     low   close  volume
# 0   ZC=F      Corn  2000-07-17  182.25  182.25  178.25  179.25   19385
# 1   ZC=F      Corn  2000-07-18  179.00  183.25  179.00  180.75   25205
# 2   ZC=F      Corn  2000-07-19  180.00  182.75  178.75  182.00   17126
# 3   ZC=F      Corn  2000-07-20  181.50  187.00  181.00  186.00   18742
# 4   ZC=F      Corn  2000-07-21  185.50  188.00  185.00  187.75   16814
# ------------------------------------------------------------------------------
#          date    open    high     low   close  volume
# 0  2000-07-17  182.25  182.25  178.25  179.25   19385
# 1  2000-07-18  179.00  183.25  179.00  180.75   25205
# 2  2000-07-19  180.00  182.75  178.75  182.00   17126
# 3  2000-07-20  181.50  187.00  181.00  186.00   18742
# 4  2000-07-21  185.50  188.00  185.00  187.75   16814
# ------------------------------------------------------------------------------
#          date   open   high     low   close  volume
# 0  2000-09-21  296.0  296.0  292.00  293.75    4842
# 1  2000-09-22  293.5  297.0  293.25  295.50    3945
# 2  2000-09-25  297.5  300.0  297.00  299.50    5073
# 3  2000-09-26  301.0  303.5  299.75  302.00    9180
# 4  2000-09-27  301.5  308.0  301.00  307.75   11145
# ------------------------------------------------------------------------------
#          date    open   high     low   close  volume
# 0  2000-01-03  117.25  117.5  116.75  116.75       2
# 1  2000-01-04  117.00  117.0  117.00  117.00      12
# 2  2000-01-05  117.25  117.5  116.75  116.75       6
# 3  2000-01-06  117.25  117.5  116.75  117.00       6
# 4  2000-01-07  117.25  117.5  116.75  117.25       6
# ------------------------------------------------------------------------------
#          date        open        high         low       close  volume
# 0  2000-01-03  636.650024  640.950012  640.950012  636.650024       0
# 1  2000-01-04  636.650024  640.950012  640.950012  629.450012       0
# 2  2000-01-05  629.450012  640.950012  640.950012  626.500000       0
# 3  2000-01-06  626.500000  640.950012  640.950012  627.299988       0
# 4  2000-01-07  627.299988  640.950012  640.950012  624.349976       0
# ------------------------------------------------------------------------------
#          date    open    high     low   close  volume
# 0  2000-09-15  491.00  493.75  490.00  493.75     445
# 1  2000-09-18  483.25  486.00  482.50  484.00     382
# 2  2000-09-19  485.00  485.50  483.50  484.25     325
# 3  2000-09-20  483.50  484.25  483.25  483.25     321
# 4  2000-09-21  486.75  488.00  486.00  486.50     330
# ------------------------------------------------------------------------------
#          date       open       high        low      close  volume
# 0  2000-03-15  17.049999  17.129999  16.809999  16.850000   11147
# 1  2000-03-16  16.790001  17.219999  16.639999  16.940001   12610
# 2  2000-03-17  17.100000  17.900000  17.000000  17.850000   24579
# 3  2000-03-20  17.500000  17.600000  17.260000  17.459999   10960
# 4  2000-03-21  17.430000  17.459999  17.219999  17.270000    8102
# ------------------------------------------------------------------------------

# %%
i = -1 
for df in dfs_arr:
    i+=1
    print(colored(f"{dfs_names_arr[i]}",attrs=['bold']))
    print(colored("***********",attrs=['bold']))
    for n,col in enumerate(list(df.columns)):
        print(f"data type of {col} is {df[col].dtype}")
    print("_______________________________________________________________")
    print("_______________________________________________________________")
# Out:
# all grains
# ***********
# data type of ticker is object
# data type of commodity is object
# data type of date is object
# data type of open is float64
# data type of high is float64
# data type of low is float64
# data type of close is float64
# data type of volume is int64
# _______________________________________________________________
# _______________________________________________________________
# corn
# ***********
# data type of date is object
# data type of open is float64
# data type of high is float64
# data type of low is float64
# data type of close is float64
# data type of volume is int64
# _______________________________________________________________
# _______________________________________________________________
# wheat
# ***********
# data type of date is object
# data type of open is float64
# data type of high is float64
# data type of low is float64
# data type of close is float64
# data type of volume is int64
# _______________________________________________________________
# _______________________________________________________________
# oat
# ***********
# data type of date is object
# data type of open is float64
# data type of high is float64
# data type of low is float64
# data type of close is float64
# data type of volume is int64
# _______________________________________________________________
# _______________________________________________________________
# rice
# ***********
# data type of date is object
# data type of open is float64
# data type of high is float64
# data type of low is float64
# data type of close is float64
# data type of volume is int64
# _______________________________________________________________
# _______________________________________________________________
# soybean
# ***********
# data type of date is object
# data type of open is float64
# data type of high is float64
# data type of low is float64
# data type of close is float64
# data type of volume is int64
# _______________________________________________________________
# _______________________________________________________________
# soybean oil
# ***********
# data type of date is object
# data type of open is float64
# data type of high is float64
# data type of low is float64
# data type of close is float64
# data type of volume is int64
# _______________________________________________________________
# _______________________________________________________________

# %%
i = -1 
for df in dfs_arr:
    i+=1
    print(colored(f"{dfs_names_arr[i]}",attrs=['bold']))
    print(colored("***********",attrs=['bold']))
    print(f"Number of rows: {df.shape[0]}\nNumber of columns: {df.shape[1]}")
    print("______________________________________________")
# Out:
# all grains
# ***********
# Number of rows: 36041
# Number of columns: 8
# ______________________________________________
# corn
# ***********
# Number of rows: 5987
# Number of columns: 6
# ______________________________________________
# wheat
# ***********
# Number of rows: 5976
# Number of columns: 6
# ______________________________________________
# oat
# ***********
# Number of rows: 5966
# Number of columns: 6
# ______________________________________________
# rice
# ***********
# Number of rows: 6130
# Number of columns: 6
# ______________________________________________
# soybean
# ***********
# Number of rows: 5979
# Number of columns: 6
# ______________________________________________
# soybean oil
# ***********
# Number of rows: 6003
# Number of columns: 6
# ______________________________________________

# %%
i = -1 
for df in dfs_arr:
    i+=1
    print(colored(f"{dfs_names_arr[i]}",attrs=['bold']))
    print(colored("***********",attrs=['bold']))
    print(df.isna().sum())
    print("______________________________________________")
# Out:
# all grains
# ***********
# ticker       0
# commodity    0
# date         0
# open         0
# high         0
# low          0
# close        0
# volume       0
# dtype: int64
# ______________________________________________
# corn
# ***********
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ______________________________________________
# wheat
# ***********
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ______________________________________________
# oat
# ***********
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ______________________________________________
# rice
# ***********
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ______________________________________________
# soybean
# ***********
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ______________________________________________
# soybean oil
# ***********
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ______________________________________________

# %%
i = -1 
for df in dfs_arr:
    i+=1
    max_value_row = df.loc[df['high'].idxmax()]
    print(colored(f"{dfs_names_arr[i]}",attrs=['bold']))
    print(colored("***********",attrs=['bold']))
    print(f"Highest high of the whole time: {max_value_row['high']}\nDate of highest high: {max_value_row['date']}")
    print("______________________________________________")
# Out:
# all grains
# ***********
# Highest high of the whole time: 2468.5
# Date of highest high: 2008-04-24
# ______________________________________________
# corn
# ***********
# Highest high of the whole time: 843.75
# Date of highest high: 2012-08-10
# ______________________________________________
# wheat
# ***********
# Highest high of the whole time: 1384.75
# Date of highest high: 2008-02-27
# ______________________________________________
# oat
# ***********
# Highest high of the whole time: 811.0
# Date of highest high: 2022-04-12
# ______________________________________________
# rice
# ***********
# Highest high of the whole time: 2468.5
# Date of highest high: 2008-04-24
# ______________________________________________
# soybean
# ***********
# Highest high of the whole time: 1794.75
# Date of highest high: 2012-09-04
# ______________________________________________
# soybean oil
# ***********
# Highest high of the whole time: 91.4000015258789
# Date of highest high: 2022-04-29
# ______________________________________________

# %%
i = -1 
for df in dfs_arr:
    i+=1
    max_value_row = df.loc[df['low'].idxmax()]
    print(colored(f"{dfs_names_arr[i]}",attrs=['bold']))
    print(colored("***********",attrs=['bold']))
    print(f"lowest low of the whole time: {max_value_row['low']}\nDate of lowest low: {max_value_row['date']}")
    print("______________________________________________")
# Out:
# all grains
# ***********
# lowest low of the whole time: 2400.0
# Date of lowest low: 2008-04-23
# ______________________________________________
# corn
# ***********
# lowest low of the whole time: 822.75
# Date of lowest low: 2012-08-22
# ______________________________________________
# wheat
# ***********
# lowest low of the whole time: 1325.0
# Date of lowest low: 2022-05-16
# ______________________________________________
# oat
# ***********
# lowest low of the whole time: 799.75
# Date of lowest low: 2022-04-12
# ______________________________________________
# rice
# ***********
# lowest low of the whole time: 2400.0
# Date of lowest low: 2008-04-23
# ______________________________________________
# soybean
# ***********
# lowest low of the whole time: 1760.5
# Date of lowest low: 2012-09-04
# ______________________________________________
# soybean oil
# ***********
# lowest low of the whole time: 89.0999984741211
# Date of lowest low: 2022-04-29
# ______________________________________________

# %%
for df in dfs_arr:
    df['date'] = pd.to_datetime(df['date'],format="%Y-%m-%d")

# %%
plt.style.use("ggplot")

# %%
splitted_dfs = [corn_df,oat_df,soybean_df,soybean_oil_df,rice_df,wheat_df]
titles_names = ['Corn','Oat','Soybean','Soybean Oil','Rice','Wheat']

def plot_variable_all_dfs(name:str) -> None:    
    fig,ax = plt.subplots(figsize = (23,12),nrows=2,ncols=3)
    fig.suptitle(f"{name} values changes with respect to time",fontsize = 19)
    counter = 0
    for i in range(2):
        for j in range(3):
            ax[i][j].plot(splitted_dfs[counter]['date'],splitted_dfs[counter][name],color='skyblue')
            ax[i][j].set_title(titles_names[counter])
            counter+=1

plot_variable_all_dfs('low')
plot_variable_all_dfs('high')
plot_variable_all_dfs('close')
plot_variable_all_dfs('open')
plot_variable_all_dfs('volume')

# %%
for df in splitted_dfs:
    df.set_index('date',inplace=True)

# %%
for year in oat_df.index.year.unique():
    df_year = oat_df[oat_df.index.year == year]

    mpf.plot(df_year,type='candle',volume=True,style='charles',title=f'Stock Price {year}', ylabel='Price', ylabel_lower='Volume')
